# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# %%
pic = 'images\pexels-olegbf-oleg-borisov-1342650.jpg'

# %%
img = image.load_img(pic,target_size=(224,224))

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
resized_img = image.img_to_array(img)
final = np.expand_dims(resized_img,axis=0)
final_img = tf.keras.applications.mobilenet_v2.preprocess_input(final)

# %%
predictions = mobile.predict(final_img)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03666591', 'lighter', 0.7516211), ('n04456115', 'torch', 0.08990826), ('n09229709', 'bubble', 0.06545832), ('n02948072', 'candle', 0.052468833), ('n03729826', 'matchstick', 0.0066506863)]]

# %%
plt.imshow(img)
